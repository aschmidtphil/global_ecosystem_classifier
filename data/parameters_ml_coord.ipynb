# %% [markdown]
# Artificial Land Covers
# Artificial-Urban-Greenspace
#
# Central Park, New York, USA: An iconic urban greenspace surrounded by dense high-rise buildings in Manhattan.
#
# Coordinates: 40.7851° N, 73.9683° W
# Artificial-Urban-Buildings
#
# Paris, France: A dense, historical city known for uniform Haussmann architecture.
#
# Coordinates: 48.8566° N, 2.3522° E
#
# New York, USA: Characterized by skyscrapers and a grid-like street pattern.
#
# Coordinates: 40.7128° N, 74.0060° W
#
# Moscow, Russia: Known for Soviet-style architecture and dense urban structures.
#
# Coordinates: 55.7558° N, 37.6173° E
#
# Lagos, Nigeria: A rapidly urbanizing city with mixed infrastructure quality.
#
# Coordinates: 6.5244° N, 3.3792° E
#
# Artificial-Agriculture-Fields
#
#
# Niedersachsen, Germany: European-style, highly managed agricultural fields.
#
# Coordinates: 52.6367° N, 9.8451° E
#
# Yangtze River Delta, China: Intensive rice paddy fields with intricate irrigation systems.
#
# Coordinates: 31.2304° N, 121.4737° E
#
# Wisconsin, USA: Known for large-scale monoculture farming.
#
# Coordinates: 44.5000° N, 89.5000° W
#
# Natural Land Covers
#
# Forests
# Natural-Forest-Boreal/Taiga
#
#
# Siberia, Russia: Expansive boreal forest with sparse human interference.
#
# Coordinates: 61.5240° N, 105.3188° E
#
# Finland (Lapland): Highly managed but expansive boreal forests.
#
# Coordinates: 67.9245° N, 26.4240° E
#
# Northern Canada: Remote, dense boreal forest with extreme seasonal climate variations.
#
# Coordinates: 56.1304° N, -106.3468° W
#
#
# Natural-Forest-Temperate
#
#
# Black Forest, Germany: Dense, diverse deciduous forest, a European temperate forest archetype.
#
# Coordinates: 48.2920° N, 8.2294° E
#
# Vosges Mountains, France: Mixed forests with clear seasonal transitions.
#
# Coordinates: 48.2200° N, 7.0600° E
#
# Yellowstone, USA: Rocky Mountain forests with rich biodiversity, combining deciduous and coniferous trees.
#
# Coordinates: 44.4280° N, 110.5885° W
#
# Deserts
# Natural-Desert-Hot
#
#
# Sahara Desert, North Africa: Expansive sand dunes and rocky plateaus with extreme arid conditions.
#
# Coordinates: 23.4162° N, 25.6628° E
#
# Kalahari Desert, Southern Africa: Semi-arid desert with sporadic vegetation.
#
# Coordinates: 23.1815° S, 24.4170° E
#
# Natural-Desert-Cold
#
# Gobi Desert, Mongolia/China: Cold desert with rocky terrain, low vegetation, and extreme temperature ranges.
#
# Coordinates: 42.7952° N, 105.0324° E
#
# Atacama Desert, Chile: One of the driest places on Earth, with unique salt flats and barren landscapes.
#
# Coordinates: 24.5000° S, 69.2500° W
#
# Natural-Desert-Semi-Arid
#
#
# Great Basin, USA: Sagebrush-covered terrain with distinctive semi-arid climate.
#
# Coordinates: 39.4412° N, 117.1853° W
#
# Patagonian Desert, Argentina: Windy, cold semi-arid desert with scrub vegetation.
#
# Coordinates: 40.9799° S, 67.8339° W
#
# Grasslands
# Natural-Grassland-Meadow
#
#
# Great Plains, USA: Expansive, temperate meadows, iconic for North American grasslands.
#
# Coordinates: 39.8283° N, 98.5795° W
#
# Scotland, British Isles: Managed meadows with high biodiversity, often used for pastoral farming.
#
# Coordinates: 56.4907° N, 4.2026° W
#
# Natural-Grassland-Steppe
#
# Mongolia: Dry, endless grassland with barely any trees, suited to nomadic herding.
#
# Coordinates: 46.8625° N, 103.8467° E
#
# Pampas, Argentina: Fertile temperate grasslands, archetype of South American grasslands.
#
# Coordinates: 36.4136° S, 60.6543° W
#
# Natural-Grassland-Savannah
#
# Serengeti, Tanzania: Grass-dominated landscape with sparse trees and unique wildlife.
#
# Coordinates: 2.3333° S, 34.8333° E
#
# Natural-Grassland-Swamp
#
# Everglades, USA: Unique wetland ecosystem in a tropical climate.
#
# Coordinates: 25.2866° N, 80.8987° W
#
# Pantanal, Brazil: One of the world’s largest tropical wetlands with significant biodiversity.
#
# Coordinates: 16.8639° S, 56.5056° W
#
# Montane Regions
# Natural-Montane-Montane Forest
#
# Himalayas, Nepal/Bhutan: High-altitude montane forests with rhododendron and coniferous trees.
#
# Coordinates: 27.7000° N, 85.3000° E
#
# Rocky Mountains, USA: Diverse montane ecosystem with coniferous forests.
#
# Coordinates: 39.5501° N, 105.7821° W
#
# Natural-Montane-Alpine Tundra
#
# Swiss Alps: High-altitude tundra with sparse vegetation and snow-covered peaks.
#
# Coordinates: 46.8182° N, 8.2275° E
#
# Andes, Peru/Bolivia: High-altitude regions with alpine vegetation and thin air.
#
# Coordinates: 13.1631° S, 72.5450° W
#
# Natural-Montane-Subalpine
#
# Cascades, USA: Subalpine forests with a mix of conifers and flowering shrubs.
#
# Coordinates: 46.8523° N, 121.7603° W
#
# Pyrenees, France/Spain: Diverse subalpine ecosystem at moderate altitude.
#
# Coordinates: 42.7663° N, 0.4130° E
